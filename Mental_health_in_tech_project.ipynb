# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghavaBusanaboina/Projects/blob/main/Mental_health_in_tech_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd drive/MyDrive/TASKS_ML_NETZWERK_ACADAMEY/Datasets/
# Out:
# /content/drive/MyDrive/TASKS_ML_NETZWERK_ACADAMEY/Datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ##Dataset Information
#
# This dataset is from a 2014 survey that measures attitudes towards mental health and frequency of mental health disorders in the tech workplace

# %% [markdown]
# ## Content
#
# This dataset contains the following data:
#
#     Timestamp
#
#     Age
#
#     Gender
#
#     Country
#
#     state: If you live in the United States, which state or territory do you live in?
#
#     self_employed: Are you self-employed?
#
#     family_history: Do you have a family history of mental illness?
#
#     treatment: Have you sought treatment for a mental health condition?
#
#     work_interfere: If you have a mental health condition, do you feel that it interferes with your work?
#
#     no_employees: How many employees does your company or organization have?
#
#     remote_work: Do you work remotely (outside of an office) at least 50% of the time?
#
#     tech_company: Is your employer primarily a tech company/organization?
#
#     benefits: Does your employer provide mental health benefits?
#
#     care_options: Do you know the options for mental health care your employer provides?
#
#     wellness_program: Has your employer ever discussed mental health as part of an employee wellness program?
#
#     seek_help: Does your employer provide resources to learn more about mental health issues and how to seek help?
#
#     anonymity: Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
#
#     leave: How easy is it for you to take medical leave for a mental health condition?
#
#     mentalhealthconsequence: Do you think that discussing a mental health issue with your employer would have negative consequences?
#
#     physhealthconsequence: Do you think that discussing a physical health issue with your employer would have negative consequences?
#
#     coworkers: Would you be willing to discuss a mental health issue with your coworkers?
#
#     supervisor: Would you be willing to discuss a mental health issue with your direct supervisor(s)?
#
#     mentalhealthinterview: Would you bring up a mental health issue with a potential employer in an interview?
#
#     physhealthinterview: Would you bring up a physical health issue with a potential employer in an interview?
#
#     mentalvsphysical: Do you feel that your employer takes mental health as seriously as physical health?
#
#     obs_consequence: Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?
#
#     comments: Any additional notes or comments

# %%
data = pd.read_csv('survey.csv')
df = data.copy()
df.head()
# Out:
#              Timestamp  Age  Gender  ... mental_vs_physical obs_consequence comments
# 0  2014-08-27 11:29:31   37  Female  ...                Yes              No      NaN
# 1  2014-08-27 11:29:37   44       M  ...         Don't know              No      NaN
# 2  2014-08-27 11:29:44   32    Male  ...                 No              No      NaN
# 3  2014-08-27 11:29:46   31    Male  ...                 No             Yes      NaN
# 4  2014-08-27 11:30:22   31    Male  ...         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
df.shape
# Out:
# (1259, 27)

# %%
df.keys()
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %%
df.isna().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
df['self_employed'].unique()
# Out:
# array([nan, 'Yes', 'No'], dtype=object)

# %%
df['self_employed'].value_counts()
# Out:
# No     1095
# Yes     146
# Name: self_employed, dtype: int64

# %%
df['self_employed'].mode()
# Out:
# 0    No
# dtype: object

# %%
df['self_employed'] = df['self_employed'].fillna('No')

# %%
df['work_interfere'].unique()
# Out:
# array(['Often', 'Rarely', 'Never', 'Sometimes', nan], dtype=object)

# %%
df['work_interfere'].value_counts()
# Out:
# Sometimes    465
# Never        213
# Rarely       173
# Often        144
# Name: work_interfere, dtype: int64

# %%
df['work_interfere'].mode()
# Out:
# 0    Sometimes
# dtype: object

# %%
df['work_interfere'] = df['work_interfere'].fillna('Sometimes')

# %%
df.drop('comments',axis=1,inplace=True)

# %%
df.keys()
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence'],
#       dtype='object')

# %%
df['state'].mode()
# Out:
# 0    CA
# dtype: object

# %%
df['state'] = df['state'].fillna('CA')

# %%
df.isna().sum()
# Out:
# Timestamp                    0
# Age                          0
# Gender                       0
# Country                      0
# state                        0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %% [markdown]
# ### Handling gender

# %%
df['Gender'].value_counts()
# Out:
# Male                                              615
# male                                              206
# Female                                            121
# M                                                 116
# female                                             62
# F                                                  38
# m                                                  34
# f                                                  15
# Make                                                4
# Woman                                               3
# Male                                                3
# Female (trans)                                      2
# Female                                              2
# Man                                                 2
# Cis Male                                            2
# Malr                                                1
# cis male                                            1
# ...

# %%
df['Gender'] = df['Gender'].apply(lambda x :x.lower())

# %%
df['Gender'].value_counts()
# Out:
# male                                              821
# female                                            183
# m                                                 150
# f                                                  53
# make                                                4
# woman                                               4
# cis male                                            3
# male                                                3
# female (trans)                                      2
# female                                              2
# man                                                 2
# cis female                                          1
# agender                                             1
# non-binary                                          1
# androgyne                                           1
# femail                                              1
# neuter                                              1
# ...

# %%
female,male = [],[]
for i in df['Gender']:
  if i[0] == 'm' or 'male' in i and 'fe' not in i:
    male.append(i)
  elif 'trans' not in i and (i[0] == 'f' or 'fe' in i or 'she' in i) or ('wo' in i and ('trans' and 'trans-female'and 'trans woman') not in i):
    female.append(i)

# %%
# df_1 = df.copy()

# %%
def gender(x):
  if x in male:
    return 'male'
  elif x in female:
    return 'female'
  else:
    return 'others'

# %%
df['Gender'] = df['Gender'].apply(gender)

# %%
df['Gender'].value_counts()
# Out:
# male      993
# female    249
# others     17
# Name: Gender, dtype: int64

# %%
df['Timestamp']
# Out:
# 0       2014-08-27 11:29:31
# 1       2014-08-27 11:29:37
# 2       2014-08-27 11:29:44
# 3       2014-08-27 11:29:46
# 4       2014-08-27 11:30:22
#                ...
# 1254    2015-09-12 11:17:21
# 1255    2015-09-26 01:07:35
# 1256    2015-11-07 12:36:58
# 1257    2015-11-30 21:25:06
# 1258    2016-02-01 23:04:31
# Name: Timestamp, Length: 1259, dtype: object

# %%
# def timestamp(ts,mode):
#   if mode == 'year':
#     return np.int(ts[0:4])
#   elif mode == 'month':
#     return np.int(ts[5:7])
#   elif mode == 'date':
#     return np.int(ts[8:10])
#   elif mode == 'hour':
#     return np.int(ts[11:13])
#   elif mode == 'min':
#     return np.int(ts[14:16])
#   elif mode == 'sec':
#     return np.int(ts[-2:])

# %%
df['year'] = df['Timestamp'].apply(lambda x:np.int(x[0:4]))
df['month'] = df['Timestamp'].apply(lambda x:np.int(x[5:7]))
df['date'] = df['Timestamp'].apply(lambda x:np.int(x[8:10]))
df['hour'] = df['Timestamp'].apply(lambda x:np.int(x[11:13]))
df['min'] = df['Timestamp'].apply(lambda x:np.int(x[14:16]))
df['sec'] = df['Timestamp'].apply(lambda x:np.int(x[-2:]))

# %%
df.drop('Timestamp',axis=1,inplace=True)

# %% [markdown]
# ## EDA

# %%
def label_function(val):
    return f'{val / 100 * len(df):.2f}\n{val:.2f}%'
def plot(name,title,kind):
  if kind == 'pie':
    fig, ax = plt.subplots(figsize=[20,10])
    df.groupby(name).size().plot(kind=kind,autopct=label_function, textprops={'fontsize': 15})
  else:
    fig, ax = plt.subplots(figsize=[15,6])
    df.groupby(name).size().plot(kind=kind)
  plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5),fontsize=15)
  plt.title(title, fontsize=15)

# %%
plot(df['Country'],title='Countries',kind='bar')

# %%
plot(df['Gender'],title='Gender',kind='pie')

# %%
plot(df['self_employed'],title='self_employed',kind='pie')

# %%
plot(df['family_history'],title='family_history of mental illness',kind='pie')

# %%
plot(df['treatment'],title='treatment for a mental health condition',kind='pie')

# %%
plot(df['work_interfere'],title='If you have a mental health condition, do you feel that it interferes with your work',kind='pie')

# %%
plot(df['no_employees'],title='How many employees does your company or organization have',kind='pie')

# %%
plot(df['remote_work'],title='Do you work remotely (outside of an office) at least 50% of the time?',kind='pie')

# %%
plot(df['tech_company'],title='Is your employer primarily a tech company/organization',kind='pie')

# %%
plot(df['benefits'],title='Does your employer provide mental health benefits?',kind='pie')

# %%
plot(df['care_options'],title='Do you know the options for mental health care your employer provides?',kind='pie')

# %%
plot(df['wellness_program'],title='Has your employer ever discussed mental health as part of an employee wellness program?',kind='pie')

# %%
plot(df['seek_help'],title='Does your employer provide resources to learn more about mental health issues and how to seek help?',kind='pie')

# %%
plot(df['anonymity'],title='Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?',kind='pie')

# %%
plot(df['leave'],title='How easy is it for you to take medical leave for a mental health condition',kind='pie')

# %%
plot(df['mental_health_consequence'],title='Do you think that discussing a mental health issue with your employer would have negative consequences',kind='pie')

# %%
plot(df['phys_health_consequence'],title='Do you think that discussing a physical health issue with your employer would have negative consequences?',kind='pie')

# %%
plot(df['coworkers'],title='Would you be willing to discuss a mental health issue with your coworkers?',kind='pie')

# %%
plot(df['supervisor'],title='Would you be willing to discuss a mental health issue with your direct supervisor(s)?',kind='pie')

# %%
plot(df['mental_health_interview'],title='would you bring up a mental health issue with a potential employer in an interview?',kind='pie')

# %%
plot(df['obs_consequence'],title='Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace',kind='pie')

# %%
plot(df['phys_health_interview'],title='Would you bring up a physical health issue with a potential employer in an interview?',kind='pie')

# %%
plot(df['mental_vs_physical'],title='will you take  mental health as seriously as physical health?',kind='pie')

# %%
# sns.barplot(y='Age',x='tech_company',hue='Gender',data=df)

# %%
df.keys()
# Out:
# Index(['Age', 'Gender', 'Country', 'state', 'self_employed', 'family_history',
#        'treatment', 'work_interfere', 'no_employees', 'remote_work',
#        'tech_company', 'benefits', 'care_options', 'wellness_program',
#        'seek_help', 'anonymity', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'year', 'month', 'date',
#        'hour', 'min', 'sec'],
#       dtype='object')

# %%
df['work_interfere'].unique()
# Out:
# array(['Often', 'Rarely', 'Never', 'Sometimes'], dtype=object)

# %%
df['no_employees'].unique()
# Out:
# array(['6-25', 'More than 1000', '26-100', '100-500', '1-5', '500-1000'],
#       dtype=object)

# %%
df['obs_consequence'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['leave'].unique()
# Out:
# array(['Somewhat easy', "Don't know", 'Somewhat difficult',
#        'Very difficult', 'Very easy'], dtype=object)

# %%
df.head()
# Out:
#    Age  Gender         Country state self_employed  ... month date hour min sec
# 0   37  female   United States    IL            No  ...     8   27   11  29  31
# 1   44    male   United States    IN            No  ...     8   27   11  29  37
# 2   32    male          Canada    CA            No  ...     8   27   11  29  44
# 3   31    male  United Kingdom    CA            No  ...     8   27   11  29  46
# 4   31    male   United States    TX            No  ...     8   27   11  30  22
#
# [5 rows x 31 columns]

# %%
{column:list(df[column].unique()) for column in df.select_dtypes('O').columns}
# Out:
# {'Country': ['United States',
#   'Canada',
#   'United Kingdom',
#   'Bulgaria',
#   'France',
#   'Portugal',
#   'Netherlands',
#   'Switzerland',
#   'Poland',
#   'Australia',
#   'Germany',
#   'Russia',
#   'Mexico',
#   'Brazil',
#   'Slovenia',
#   'Costa Rica',
#   'Austria',
#   'Ireland',
#   'India',
#   'South Africa',
#   'Italy',
#   'Sweden',
#   'Colombia',
#   'Latvia',
#   'Romania',
#   'Belgium',
#   'New Zealand',
#   'Zimbabwe',
#   'Spain',
#   'Finland',
#   'Uruguay',
#   'Israel',
#   'Bosnia and Herzegovina',
#   'Hungary',
#   'Singapore',
#   'Japan',
#   'Nigeria',
#   'Croatia',
#   'Norway',
#   'Thailand',
#   'Denmark',
#   'Bahamas, The',
#   'Greece',
#   'Moldova',
#   'Georgia',
#   'China',
#   'Czech Republic',
#   'Philippines'],
#  'Gender': ['female', 'male', 'others'],
#  'anonymity': ['Yes', "Don't know", 'No'],
#  'benefits': ['Yes', "Don't know", 'No'],
#  'care_options': ['Not sure', 'No', 'Yes'],
# ...

# %% [markdown]
# ### catagorical columns

# %%
cat_columns = [column for column in df.select_dtypes('O').columns]

# %%
cat_columns
# Out:
# ['Gender',
#  'Country',
#  'state',
#  'self_employed',
#  'family_history',
#  'treatment',
#  'work_interfere',
#  'no_employees',
#  'remote_work',
#  'tech_company',
#  'benefits',
#  'care_options',
#  'wellness_program',
#  'seek_help',
#  'anonymity',
#  'leave',
#  'mental_health_consequence',
#  'phys_health_consequence',
#  'coworkers',
#  'supervisor',
#  'mental_health_interview',
#  'phys_health_interview',
#  'mental_vs_physical',
#  'obs_consequence']

# %%
df1 = df.copy()
df1.head()
# Out:
#    Age  Gender         Country state self_employed  ... month date hour min sec
# 0   37  female   United States    IL            No  ...     8   27   11  29  31
# 1   44    male   United States    IN            No  ...     8   27   11  29  37
# 2   32    male          Canada    CA            No  ...     8   27   11  29  44
# 3   31    male  United Kingdom    CA            No  ...     8   27   11  29  46
# 4   31    male   United States    TX            No  ...     8   27   11  30  22
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1 = df1.apply(LabelEncoder().fit_transform)

# %%
df1.head()
# Out:
#    Age  Gender  Country  state  self_employed  ...  month  date  hour  min  sec
# 0   25       0       45     10              0  ...      6    23    11   29   31
# 1   32       1       45     11              0  ...      6    23    11   29   37
# 2   20       1        7      2              0  ...      6    23    11   29   44
# 3   19       1       44      2              0  ...      6    23    11   29   46
# 4   19       1       45     37              0  ...      6    23    11   30   22
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Dividing Dependent and Independent variables

# %%
x = df1.drop('treatment',axis=1)
y = df1['treatment']

# %% [markdown]
# ## We can see our dataset is balanced

# %%
df1['treatment'].value_counts()
# Out:
# 1    637
# 0    622
# Name: treatment, dtype: int64

# %%
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %% [markdown]
# ## Splitting data into train and test sets

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=1)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((944, 30), (315, 30), (944,), (315,))

# %% [markdown]
# ## K Nearest Neighbour:

# %% [markdown]
# Here i'm using KNN because our target variable is in binary classification

# %%
from sklearn.neighbors import KNeighborsClassifier
acc = []
for i in range(50):
  knn = KNeighborsClassifier(n_neighbors=i)
  score = cross_val_score(knn,x,y,cv=5)
  acc.append(score.mean())

# %%
plt.figure(figsize=(20,5))
plt.plot(range(50),acc,color='blue',ls='--',marker='o',markerfacecolor='red',markersize=10)
plt.title('Accuracy_rate vs K value')
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
knn = KNeighborsClassifier(n_neighbors=35)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=35, p=2,
#                      weights='uniform')

# %%
y_pred = knn.predict(x_test)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[86, 71],
#        [75, 83]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.55      0.54       157
#            1       0.54      0.53      0.53       158
#
#     accuracy                           0.54       315
#    macro avg       0.54      0.54      0.54       315
# weighted avg       0.54      0.54      0.54       315

# %% [markdown]
# ## Logistic Regression

# %%
def scores(estimator,y_pred):
  """ This function calculates the score,score,confusion matrix"""
  acc_train = estimator.score(x_train,y_train)*100
  acc_test = estimator.score(x_test,y_test)*100
  tn,fp,fn,tp = confusion_matrix(y_test,y_pred).ravel()
  cm = confusion_matrix(y_test,y_pred)
  correct = tn+tp
  incorrect = fp+fn
  return acc_train, acc_test, cm, correct, incorrect

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = lr.predict(x_test)
training_acc,test_acc,cm,correct,incorrect = scores(estimator=lr,y_pred=y_pred)
print(f'Training accuracy is --> {training_acc}')
print(f'Test accuracy is ------> {test_acc}')
print(f'confusion matrix \n {cm}')
print(f'Number of correct predictions ={correct}')
print(f'Number of incorrect predictions ={incorrect}')
# Out:
# Training accuracy is --> 74.25847457627118
# Test accuracy is ------> 69.84126984126983
# confusion matrix
#  [[104  53]
#  [ 42 116]]
# Number of correct predictions =220
# Number of incorrect predictions =95

# %% [markdown]
# Hyperparameters tuning for logistic regression

# %%
LR = LogisticRegression()
LRparam_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'penalty': ['l1', 'l2'],
    'max_iter': list(range(100,800,100)),
}
LR_search = GridSearchCV(LR, param_grid=LRparam_grid, refit = True, verbose = 3, cv=5)

# fitting the model for grid search 
LR_search.fit(x_train , y_train)
# Out:
# Fitting 5 folds for each of 98 candidates, totalling 490 fits
# [CV] C=0.001, max_iter=100, penalty=l1 ...............................
# [CV] ..... C=0.001, max_iter=100, penalty=l1, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=100, penalty=l1 ...............................
# [CV] ..... C=0.001, max_iter=100, penalty=l1, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=100, penalty=l1 ...............................
# [CV] ..... C=0.001, max_iter=100, penalty=l1, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=100, penalty=l1 ...............................
# [CV] ..... C=0.001, max_iter=100, penalty=l1, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=100, penalty=l1 ...............................
# [CV] ..... C=0.001, max_iter=100, penalty=l1, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=100, penalty=l2 ...............................
# [CV] ... C=0.001, max_iter=100, penalty=l2, score=0.603, total=   0.0s
# ...

# %%
LR_search.best_params_
# Out:
# {'C': 1000, 'max_iter': 600, 'penalty': 'l2'}

# %%
print('Mean Accuracy: %.3f' % LR_search.best_score_)
print('Config: %s' % LR_search.best_params_)
# Out:
# Mean Accuracy: 0.709
# Config: {'C': 1000, 'max_iter': 600, 'penalty': 'l2'}

# %%
y_pred = LR_search.predict(x_test)
print(accuracy_score(y_test,y_pred),'\n')
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.6888888888888889
#
# [[102  55]
#  [ 43 115]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.65      0.68       157
#            1       0.68      0.73      0.70       158
#
#     accuracy                           0.69       315
#    macro avg       0.69      0.69      0.69       315
# weighted avg       0.69      0.69      0.69       315

# %%
params = {'learning_rate':np.linspace(0.05,0.30,6),
          'max_depth' : np.arange(3,15),
          'min_child_weight':np.arange(1,8,2),
          'gamma':np.arange(0,0.5,0.1),
          'colsample_bytree':np.arange(0.3,0.8,0.1)}

# %% [markdown]
# ## Extreme Gradient boosting Algorithm

# %%
import xgboost

# %%
xgb = xgboost.XGBClassifier()

# %%
grid_search = GridSearchCV(xgb,param_grid=params,scoring='accuracy',cv=5,verbose=5)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 7200 candidates, totalling 36000 fits
# [CV] colsample_bytree=0.3, gamma=0.0, learning_rate=0.05, max_depth=3, min_child_weight=1
# [CV]  colsample_bytree=0.3, gamma=0.0, learning_rate=0.05, max_depth=3, min_child_weight=1, score=0.762, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.0, learning_rate=0.05, max_depth=3, min_child_weight=1
# [CV]  colsample_bytree=0.3, gamma=0.0, learning_rate=0.05, max_depth=3, min_child_weight=1, score=0.757, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.0, learning_rate=0.05, max_depth=3, min_child_weight=1
# [CV]  colsample_bytree=0.3, gamma=0.0, learning_rate=0.05, max_depth=3, min_child_weight=1, score=0.762, total=   0.1s
# [CV] colsample_bytree=0.3, gamma=0.0, learning_rate=0.05, max_depth=3, min_child_weight=1
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# ...

# %%
grid_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.6000000000000001,
#               gamma=0.4, learning_rate=0.05, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
xgb = xgboost.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.6000000000000001,
              gamma=0.4, learning_rate=0.05, max_delta_step=0, max_depth=3,
              min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
              nthread=None, objective='binary:logistic', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
              silent=None, subsample=1, verbosity=1)

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.6000000000000001,
#               gamma=0.4, learning_rate=0.05, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred = xgb.predict(x_test)
training_acc,test_acc,cm,correct,incorrect = scores(estimator=xgb,y_pred=y_pred)
print(f'Training accuracy is --> {training_acc}')
print(f'Test accuracy is ------> {test_acc}')
print(f'confusion matrix \n {cm}')
print(f'Number of correct predictions   ={correct}')
print(f'Number of incorrect predictions ={incorrect}')
# Out:
# Training accuracy is --> 80.1906779661017
# Test accuracy is ------> 73.33333333333333
# confusion matrix
#  [[104  53]
#  [ 31 127]]
# Number of correct predictions   =231
# Number of incorrect predictions =84

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# 1.Cases show that more than 50% of people surveyed in countries like US,Australia and Canada undergo treatment for mental ailments.

# %% [markdown]
# 2.Nearly 88% people are not self employed so they might be get bored, their brain filled with anxiety it leads to some mental disorders

# %% [markdown]
# 3.The surveyed people agree that their mental health somewhat affects their productivity at work.

# %% [markdown]
# 4.People feel that sharing about their mental or physical health with employers would help them a littlebit relief.

# %% [markdown]
# 5.People feel that their employers somewhat easily sanction leave for mental health issues.The reason maybe that the employer does not want to take any risk of overloading the patient with work.
